# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import requests
from bs4 import BeautifulSoup as BS
import re
import warnings
import folium
import bokeh
from numpy import NaN
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)

# %%
# !pip install selenium

# %%
import scrapy

# %%
# !pip install pybaseball

# %%
from pybaseball import pitching_stats

# %%
from pybaseball import statcast_single_game,statcast_pitcher,pitching_stats_bref

# %%
#data = pitching_stats(2012, 2016)

# %%
from pybaseball import playerid_lookup
from pybaseball import statcast_pitcher

# %%
playerid_lookup('kershaw', 'clayton')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   kershaw    clayton     477132  kersc001  kershcl01           2036
#
#    mlb_played_first  mlb_played_last
# 0            2008.0           2019.0

# %%
kershaw_stats = statcast_pitcher('2017-06-01', '2017-07-01', 477132)
# Out:
# Gathering Player Data

# %%
kershaw_stats
# Out:
#     pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0           SL  2017-06-29           87.2         1.0847         6.4020
# 1           SL  2017-06-29           86.9         1.0178         6.4313
# 2           CU  2017-06-29           72.6         0.6014         6.4468
# 3           FF  2017-06-29           91.3         1.0190         6.2792
# 4           CU  2017-06-29           71.6         0.5375         6.4436
# 5           SL  2017-06-29           86.1         1.1317         6.3866
# 6           CU  2017-06-29           71.8         0.5808         6.4214
# 7           FF  2017-06-29           92.3         0.8646         6.3025
# 8           FF  2017-06-29           92.1         1.0603         6.3496
# 9           FF  2017-06-29           91.8         1.0613         6.3376
# 10          SL  2017-06-29           87.4         1.1776         6.3232
# 11          SL  2017-06-29           90.6         1.0775         6.3543
# ...

# %%
slider_stats = kershaw_stats.where(kershaw_stats.pitch_type == 'SL')

# %%
slider_stats.describe()
# Out:
#        release_speed  release_pos_x  release_pos_z         batter   pitcher  \
# count     210.000000     210.000000     210.000000     210.000000     210.0
# mean       87.962381       1.052939       6.417619  517248.957143  477132.0
# std         1.524996       0.171441       0.083629   61762.186947       0.0
# min        81.700000       0.655100       6.168300  405395.000000  477132.0
# 25%        87.000000       0.910825       6.359325  457711.250000  477132.0
# 50%        88.100000       1.070400       6.417000  527038.000000  477132.0
# 75%        89.000000       1.193575       6.470075  570267.000000  477132.0
# max        90.900000       1.372800       6.649700  624424.000000  477132.0
#
#        spin_dir  spin_rate_deprecated  break_angle_deprecated  \
# count       0.0                   0.0                     0.0
# mean        NaN                   NaN                     NaN
# std         NaN                   NaN                     NaN
# ...

# %%
from pybaseball import schedule_and_record

# %%
data1927 = schedule_and_record(1927, 'NYY')

# %%
data1927.head(20)
# Out:
#                  Date   Tm Home_Away  Opp   W/L     R   RA   Inn   W-L  Rank  \
# 1     Tuesday, Apr 12  NYY      Home  PHA     W   8.0  3.0   9.0   1-0   1.0
# 2   Wednesday, Apr 13  NYY      Home  PHA     W  10.0  4.0   9.0   2-0   1.0
# 3    Thursday, Apr 14  NYY      Home  PHA     T   9.0  9.0  10.0   2-0   1.0
# 4      Friday, Apr 15  NYY      Home  PHA     W   6.0  3.0   9.0   3-0   1.0
# 5    Saturday, Apr 16  NYY      Home  BOS     W   5.0  2.0   9.0   4-0   1.0
# 6      Sunday, Apr 17  NYY      Home  BOS     W  14.0  2.0   9.0   5-0   1.0
# 7      Monday, Apr 18  NYY      Home  BOS     W   3.0  0.0   9.0   6-0   1.0
# 8     Tuesday, Apr 19  NYY      Home  BOS     L   3.0  6.0   9.0   6-1   1.0
# 9   Wednesday, Apr 20  NYY         @  PHA     L   5.0  8.0   9.0   6-2   1.0
# 10   Thursday, Apr 21  NYY         @  PHA     W  13.0  6.0   9.0   7-2   1.0
# 11   Saturday, Apr 23  NYY         @  PHA  L-wo   3.0  4.0   9.0   7-3   1.0
# ...

# %%
# !pip install mechanize

# %%
response = requests.get('http://www.baseball-reference.com/play-index/game_finder.cgi?request=1&match=basic&series=any&series_game=any&min_year_game=2006&max_year_game=2006&Role=GS&DEC=any&WL=any&team_id=ANA&opp_id=ANY&game_length=any&throws=any&HV=any&is_birthday=either&temperature_min=0&temperature_max=120&wind_speed_min=0&wind_speed_max=90&as=result_pitcher&class=player&offset=0&type=p&c1criteria=IPouts&c1gtlt=gt&c1val=6&c2criteria=ER&c2gtlt=lt&c2val=3&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=date_game&number_matched=2?request=1&match=basic&series=any&series_game=any&min_year_game=2006&max_year_game=2006&Role=GS&DEC=any&WL=any&team_id=ANA&opp_id=ANY&game_length=any&throws=any&HV=any&is_birthday=either&temperature_min=0&temperature_max=120&wind_speed_min=0&wind_speed_max=90&as=result_pitcher&class=player&offset=0&type=p&c1criteria=IPouts&c1gtlt=gt&c1val=6&c2criteria=ER&c2gtlt=lt&c2val=3&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=date_game&number_matched=2brandendahlem%3A%3Abrandendahlem%3A%3A61ed124433c310575cc8345cce685857yes?')

# %%
response.status_code
# Out:
# 200

# %%
result_text = response.text

# %%
soup = BS(result_text, 'html.parser')

# %%
soup.find('table');

# %%
table = soup.find('table', {'class': "sortable stats_table"})

# %%
print(table);
# Out:
# <table class="sortable stats_table" data-cols-to-freeze="2" id="ajax_result_table"><caption>Results</caption>
# <colgroup><col/><col/><col class="sort_col"/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr>
# <th aria-label=" Rank This is a count of the rows from top to bottom. It is recalculated following the sorting of a column." class="tooltip ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="&lt;strong&gt;Rank&lt;/strong&gt;&lt;br&gt;This is a count of the rows from top to bottom.&lt;br&gt;It is recalculated following the sorting of a column." scope="col">Rk</th>
# ...

# %%
pd.read_html(str(table));

# %%
import selenium

# %%
from selenium import webdriver

# %%
import selenium
from bs4 import BeautifulSoup as BS
from selenium import webdriver
from selenium.webdriver.common.keys import Keys


driver = webdriver.Chrome();

dates = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018'];
teamNames = ['ANA','HOU','OAK','TOR','ATL','MIL','STL','CHC','ARI','LAD','SFG','CLE','SEA','FLA','NYM','WSN','BAL','SDP','PHI','PIT','TEX','TBD','BOS','CIN','COL','KCR','DET','MIN','CHW','NYY'];

url = 'https://www.baseball-reference.com/play-index/game_finder.cgi?request=1&match=basic&series=any&series_game=any&min_year_game='+ dates[0] + '&max_year_game=' + dates[0] + '&Role=anyGS&DEC=any&WL=any&team_id=' + teamNames[0] + '&opp_id=ANY&game_length=any&throws=any&HV=any&is_birthday=either&temperature_min=0&temperature_max=120&wind_speed_min=0&wind_speed_max=90&as=result_pitcher&class=player&offset=0&type=p&c1criteria=IPouts&c1gtlt=gt&c1val=6&c2criteria=ER&c2gtlt=lt&c2val=3&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=date_game&number_matched=1'

driver.get(url)

# html = browser.page_source

# soup = BS(html, "html.parser")

# table4 = soup.find('table',{'class': "sortable stats_table now_sortable sliding_cols"})

# %%
#import selenium
#from bs4 import BeautifulSoup as BS
#from selenium import webdriver
#from selenium.webdriver.common.keys import Keys


#driver = webdriver.Chrome();

#dates = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018'];
#teamNames = ['ANA','HOU','OAK','TOR','CLE','SEA','BAL','TEX','TBD','BOS','KCR','DET','MIN','CHW','NYY'];

#url4 = 'https://www.baseball-reference.com/play-index/season_finder.cgi?request=1&sum=0&as=result_pitcher&offset=0&type=p&min_year_season='+ dates[0] +'&max_year_season='+ dates[0] +'&min_season=1&max_season=-1&min_age=0&max_age=99&lg_ID=lgAL&lgAL_team=tm'+ teamNames[0] +'&lgNL_team=ANY&lgFL_team=tmAny&lgAA_team=tmAny&lgPL_team=tmAny&lgUA_team=tmAny&lgNA_team=tmAny&isActive=either&isHOF=either&isAllstar=either&throws=any&role=anyrole&games_started=60&games_relieved=80&qualifiersSeason=nomin&minIpValS=162&minDecValS=14&mingamesValS=40&qualifiersCareer=nomin&minIpValC=1000&minDecValC=100&mingamesValC=200&c1gtlt=gt&c2gtlt=gt&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=year_id&number_matched=1&order_by_asc=1'

#driver.get(url4);

# html = browser.page_source

# soup = BS(html, "html.parser")

# table4 = soup.find('table',{'class': "sortable stats_table now_sortable sliding_cols"})

# %%
#import selenium
#from bs4 import BeautifulSoup as BS
#from selenium import webdriver
#from selenium.webdriver.common.keys import Keys


#driver1 = webdriver.Chrome();

#dates = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018'];
#teamNames2 = ['ATL','MIL','STL','CHC','ARI','LAD','SFG','FLA','NYM','WSN','SDP','PHI','PIT','CIN','COL'];



#url1 = 'https://www.baseball-reference.com/play-index/season_finder.cgi?request=1&sum=0&as=result_pitcher&offset=0&type=p&min_year_season='+ dates[0] +'&max_year_season='+ dates[0] +'&min_season=1&max_season=-1&min_age=0&max_age=99&lg_ID=lgNL&lgAL_team=tmANY&lgNL_team=tm'+ teamNames2[0] +'&lgFL_team=tmAny&lgAA_team=tmAny&lgPL_team=tmAny&lgUA_team=tmAny&lgNA_team=tmAny&isActive=either&isHOF=either&isAllstar=either&throws=any&role=anyrole&games_started=60&games_relieved=80&qualifiersSeason=nomin&minIpValS=162&minDecValS=14&mingamesValS=40&qualifiersCareer=nomin&minIpValC=1000&minDecValC=100&mingamesValC=200&c1gtlt=gt&c2gtlt=gt&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=year_id&number_matched=1&order_by_asc=1'

#driver1.get(url1);

# %%
#import selenium
#from bs4 import BeautifulSoup as BS
#from selenium import webdriver
#from selenium.webdriver.common.keys import Keys


#browser1 = webdriver.Chrome();

#dates1 = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']
#teamNames1 = ['ANA','HOU','OAK','TOR','ATL','MIL','STL','CHC','ARI','LAD','SFG','CLE','SEA','FLA','NYM','WSN','BAL','SDP','PHI','PIT','TEX','TBD','BOS','CIN','COL','KCR','DET','MIN','CHW','NYY'];


#url2 = 'https://www.baseball-reference.com/play-index/game_finder.cgi?request=1&match=basic&series=any&series_game=any&min_year_game='+ dates1[0] +'&max_year_game='+ dates1[0] +'&Role=GS&DEC=any&WL=any&team_id='+ teamNames1[0] +'&opp_id=ANY&game_length=any&throws=any&HV=any&is_birthday=either&temperature_min=0&temperature_max=120&wind_speed_min=0&wind_speed_max=90&as=result_pitcher&class=player&offset=0&type=p&c1gtlt=gt&c2gtlt=gt&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=SO&number_matched=1'

#browser1.get(url2);

# %%
#Login_button = browser.find_element_by_xpath('//*[@id="div_9423262454"]/p[3]/a').click()
# Login_button = browser.find_element_by_xpath('//*[@class="section_content"]/p[3]/a').click();

# Login_button = browser.find_elements_by_class_name('section_content')[0].click()
#print(Login_button);

# %%
username = driver.find_element_by_xpath('//*[@id="loginform"]/form/div/div/input')

password = driver.find_element_by_xpath('//*[@id="loginform"]/form/div[2]/div/input')

# %%
username.send_keys("brandendahlem")
password.send_keys("1928374655Bd!")

driver.find_element_by_xpath('//*[@id="loginform"]/form/div[4]/div/input').click()

# %%
# html = browser.page_source

# %%
# soup = BS(html, "html.parser")

# table4 = soup.find('table',{'class': "sortable stats_table now_sortable sliding_cols"})

# ******************************
# ******************************
# ******************************



data = []

for date in dates:
    
    for team in teamNames:
    
        url = 'https://www.baseball-reference.com/play-index/game_finder.cgi?request=1&match=basic&series=any&series_game=any&min_year_game='+ date + '&max_year_game=' + date + '&Role=anyGS&DEC=any&WL=any&team_id=' + team + '&opp_id=ANY&game_length=any&throws=any&HV=any&is_birthday=either&temperature_min=0&temperature_max=120&wind_speed_min=0&wind_speed_max=90&as=result_pitcher&class=player&offset=0&type=p&c1criteria=IPouts&c1gtlt=gt&c1val=6&c2criteria=ER&c2gtlt=lt&c2val=3&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=date_game&number_matched=1'

        driver.get(url);

        html = driver.page_source

        soup = BS(html, "html.parser")

        table = soup.find('table',{'class': "sortable stats_table now_sortable sliding_cols"})
    
        data.append(table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-05efb268e5da> in <module>()
# ...

# %%
#data = []

#for date in dates:
    
#    for team in teamNames:
    
#        url = 'https://www.baseball-reference.com/play-index/game_finder.cgi?request=1&match=basic&series=any&series_game=any&min_year_game='+ date + '&max_year_game=' + date + '&Role=anyGS&DEC=any&WL=any&team_id=' + team + '&opp_id=ANY&game_length=any&throws=any&HV=any&is_birthday=either&temperature_min=0&temperature_max=120&wind_speed_min=0&wind_speed_max=90&as=result_pitcher&class=player&offset=0&type=p&c1criteria=IPouts&c1gtlt=gt&c1val=6&c2criteria=ER&c2gtlt=lt&c2val=3&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=date_game&number_matched=1'

#        driver.get(url);

#        html = browser.page_source

#        soup = BS(html, "html.parser")
#
##        table = soup.find('table',{'class': "sortable stats_table now_sortable sliding_cols"})
    
#        data.append(table) ;#

# %%
#season_data_nl = []

#for date in dates:
    
 #   for team in teamNames2:
    
#        url1 = 'https://www.baseball-reference.com/play-index/season_finder.cgi?request=1&sum=0&as=result_pitcher&offset=0&type=p&min_year_season='+ date +'&max_year_season='+ date +'&min_season=1&max_season=-1&min_age=0&max_age=99&lg_ID=lgAL&lgAL_team=tm'+ team +'&lgNL_team=ANY&lgFL_team=tmAny&lgAA_team=tmAny&lgPL_team=tmAny&lgUA_team=tmAny&lgNA_team=tmAny&isActive=either&isHOF=either&isAllstar=either&throws=any&role=anyrole&games_started=60&games_relieved=80&qualifiersSeason=nomin&minIpValS=162&minDecValS=14&mingamesValS=40&qualifiersCareer=nomin&minIpValC=1000&minDecValC=100&mingamesValC=200&c1gtlt=gt&c2gtlt=gt&c3gtlt=gt&c4gtlt=gt&c5gtlt=gt&c5val=1.0&location=pob&locationMatch=is&orderby=year_id&number_matched=1&order_by_asc=1'
#
 #       driver1.get(url1);

#        html = driver1.page_source

#        soup = BS(html, "html.parser")

#        table = soup.find('table',{'class': "sortable stats_table now_sortable sliding_cols"})
    
#season_data_nl.append(table)

# %%
#nl_seasons = pd.DataFrame()

#for d in season_data_nl:
 #   nl_seasons = nl_seasons.append(pd.read_html(str(d)), ignore_index=True)

# %%
#al_seasons

# %%
#al_seasons = pd.DataFrame()

#for d in season_data_al:
#   al_seasons = al_seasons.append(pd.read_html(str(d)), ignore_index=True)

# %%
#all_seasons = pd.concat([al_seasons,nl_seasons])

# %%
#al_seasons.to_csv('al_seasons.csv',index=False)

#nl_seasons.to_csv('nl_seasons.csv',index=False)

#all_seasons.to_csv('all_seasons.csv',index=False)

# %%
# pd.read_html(str(data[0]))

#for d in data2:
#    pd.read_html(str(d))

# %%
full_quality = pd.DataFrame()

for d in data:
    full_quality = full_quality.append(pd.read_html(str(d)), ignore_index=True)

# %%
#all_starts = pd.DataFrame()

#for d in data2:
#    all_starts = all_starts.append(pd.read_html(str(d)), ignore_index=True)

# %%
print(type(all_starts))

# %%
full_quality.describe()

# %%
#all_starts.describe()

# %%
full_quality = full_quality.drop(full_quality.loc[full_quality['Rk']=='Rk'].index)

# %%
full_quality.loc[full_quality['Tm']=='TBD','Tm'] = 'TBR'

full_quality.loc[full_quality['Tm'] == 'FLA', 'Tm'] = 'MIA'

# %%
all_starts = all_starts.drop(all_starts.loc[all_starts['Rk']=='Rk'].index)

# %%
all_starts.loc[all_starts['Tm']=='TBD','Tm'] = 'TBR'

all_starts.loc[all_starts['Tm'] == 'FLA', 'Tm'] = 'MIA'

all_starts.IP.astype(float)

# %%
all_starts = all_starts.dropna(how='all')

# %%
Counter(all_starts.Tm).most_common()

# %%
Counter(all_seasons.Tm).most_common()

# %%
all_seasons.loc[all_seasons['Tm']=='TBD','Tm'] = 'TBR'

all_seasons.loc[all_seasons['Tm'] == 'FLA', 'Tm'] = 'MIA'

# %%
all_seasons = all_seasons.drop(all_seasons.loc[all_seasons['Tm']=='Tm'].index)

# %%
all_seasons.head()

# %%
all_starts.IP.astype(float);

# %%
complete_games_plus = all_starts.loc[all_starts['IP'] == '10.0']

# %%
complete_games_plus.loc[35538]

# %%
Counter(all_starts.IP).most_common()

# %%
full_quality.to_csv('full_quality.csv',index=False)

all_starts.to_csv('all_starts.csv',index=False)

# %%
pd.read_csv('all_starts.csv')
